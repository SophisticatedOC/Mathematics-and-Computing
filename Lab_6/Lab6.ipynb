# %%
import itertools

'''
s = {1, 2, 5}
permutations = list(itertools.permutations(s))
for perm in permutations:
    print(perm)

print("Number of permutations:", len(permutations))
'''
'''
s = {'j', 'NaN', 0, 3}
permutations = list(itertools.permutations(s, 2))
for perm in permutations:
    print(perm)
    
print("Number of 2-elemet permutations:", len(permutations))
'''
'''
s = [0, 7, 0, 0, 7, 7]
permutations = list(itertools.permutations(s, 5))
unique_permutations = list(set(permutations))
for perm in unique_permutations:
    print(perm)

print("Number of unique 5 element permutations:", len(unique_permutations))
'''

s = [15, 24, 15, float('inf'), 24, 2, float('inf')]
permutations = list(itertools.permutations(s, 5))
unique_permutations = list(set(permutations))
for perm in unique_permutations:
    print(perm)

print("Number of unique 5 element permutations:", len(unique_permutations))
# Out:
# (2, 15, inf, 15, 24)
# (15, inf, 15, inf, 2)
# (inf, 15, 15, inf, 2)
# (inf, 2, 15, 15, inf)
# (inf, 24, 15, 24, 15)
# (15, 24, 15, inf, inf)
# (24, 2, 24, inf, inf)
# (inf, inf, 15, 24, 15)
# (15, 15, 2, inf, 24)
# (24, inf, 15, 2, inf)
# (inf, inf, 15, 24, 24)
# (24, 15, 15, inf, 24)
# (24, 15, 2, 24, 15)
# (15, 24, inf, 15, 24)
# (15, 2, inf, 24, 24)
# (15, 24, 15, inf, 2)
# (15, 24, inf, 24, 2)
# (24, inf, 24, 15, inf)
# (24, 2, 15, 15, inf)
# (inf, 24, 2, 24, inf)
# (24, 2, inf, 15, inf)
# (24, inf, 24, 15, 2)
# (15, 15, 24, inf, 24)
# (24, 24, 15, 2, inf)
# (15, 2, 24, 24, inf)
# (15, inf, inf, 15, 24)
# (inf, 15, inf, 24, 2)
# (15, 24, inf, 24, 15)
# (15, 15, inf, 2, 24)
# (24, inf, 24, inf, 2)
# (2, 24, 15, 15, inf)
# (inf, 2, 15, inf, 15)
# (inf, 2, 15, inf, 24)
# (2, inf, 15, 15, inf)
# (inf, inf, 24, 2, 24)
# (2, 24, 15, inf, inf)
# (24, inf, 24, 15, 15)
# (15, 24, 24, 2, inf)
# (2, 15, 24, 24, inf)
# (24, 15, 24, 2, 15)
# (inf, 15, inf, 24, 15)
# (inf, 15, inf, 2, 15)
# ...
