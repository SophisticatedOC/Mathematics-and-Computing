# %%
import numpy as np
import matplotlib.pyplot as plt


for i in range(2):
    print(i)
    

values =[0,1]
for value in values:
    print(value)
for i, values in enumerate(values):
    print('iteration:',i,'value=',values)
    
    
a = [2,3,4,5,6,7]
b = sum(a)
print(b)
print(sum(a))

for i, values in enumerate(a):
    a_sum+=value
    print(a_sum)
    
cumulative_a = np.cumsum(a)
print(cumulative_a)

a.append(a_sum)
print(a)
plt.plot(cumulative_a,'ro')
plt.plot(a,'bo')

plt.plot(cumulative_a)



array_random=np.random.randn(2)
print(array_random)


print(np.random.uniform(-10,10,5))


plt.plot(array_random,'ro')


b = np.random.randn(5)
cumulative_product = np.cumprod(b)
print(cumulative_product)


update_list = np.hstack((b,cumulative_product[-1]))
print(update_list)
# Out:
# 0
# 1
# 0
# 1
# iteration: 0 value= 0
# iteration: 1 value= 1
# 27
# 27
# 25
# 26
# 27
# 28
# 29
# 30
# [ 2  5  9 14 20 27]
# [2, 3, 4, 5, 6, 7, 30]
# [-0.46335149 -0.93652122]
# [ 0.89254847 -8.63182716  8.99728249 -8.20120667  9.81662222]
# [-1.9954775  -1.21362478 -0.9835136   0.08888045  0.10832442]
# [-1.9954775   0.60818765  0.81039347 -0.09037033  1.21876541 -1.9954775
#  -1.21362478 -0.9835136   0.08888045  0.10832442]
